# %% [markdown]
# # Grafication the dataset of the channels

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import os

carpeta = 'Data_messages'
dataframes = []
for archivo in os.listdir(carpeta):
    if archivo.endswith('.csv'):  # Verificar si el archivo es un archivo CSV
        ruta = os.path.join(carpeta, archivo)  # Obtener la ruta completa del archivo
        df = pd.read_csv(ruta)  # Leer el archivo CSV y crear un DataFrame
        dataframes.append(df)

# Concatenar todos los DataFrames en uno solo
merged_df = pd.concat(dataframes, ignore_index=True)

# Guardar el DataFrame resultante en un archivo CSV
merged_df.to_csv('Data_messages/merged_dataset.csv', index=False)

# %%
df = pd.read_csv('Data_messages/merged_dataset.csv')
df
# Out:
#       channel_name         user  \
# 0           varios  U071GEQ4J13
# 1           varios  U071GEQ4J13
# 2           varios  U070C5QQS5U
# 3           varios  U070C5QQS5U
# 4           varios  U070C5QQS5U
# ..             ...          ...
# 706  prueba-prueba  U070SKGJ63E
# 707  prueba-prueba  U070C5QQS5U
# 708  prueba-prueba  U070SKGJ63E
# 709  prueba-prueba  U070C5QQS5U
# 710  prueba-prueba  U070C5QQS5U
#
#                                                   text            ts
# 0                                   y el ultimo jajaja  1.714593e+09
# 1                  <@U071GEQ4J13> se ha unido al canal  1.714590e+09
# 2                                por el canal varios 2  1.714584e+09
# 3                                por el canal varios 2  1.714584e+09
# 4                                por el canal varios 2  1.714584e+09
# ..                                                 ...           ...
# 706  Hi <@U070C5QQS5U>, thanks for the message! I'v...  1.714581e+09
# ...

# %%
user_freq = df['user'].value_counts()

# Graficar
plt.figure(figsize=(10, 6))
user_freq.plot(kind='bar')
plt.title('Frecuencia de Mensajes por Usuario')
plt.xlabel('Usuario')
plt.ylabel('Cantidad de Mensajes')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Calcular la frecuencia de mensajes por usuario y seleccionar los top N usuarios
top_n_users = 10
user_freq = df['user'].value_counts().nlargest(top_n_users)

# Graficar
plt.figure(figsize=(10, 6))
user_freq.plot(kind='bar')
plt.title(f'Top {top_n_users} Usuarios con Más Mensajes')
plt.xlabel('Usuario')
plt.ylabel('Cantidad de Mensajes')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Calcular la frecuencia de mensajes por usuario
user_freq = df['user'].value_counts()

# Graficar
plt.figure(figsize=(8, 8))
user_freq.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Distribución de Mensajes por Usuario')
plt.ylabel('')
plt.tight_layout()
plt.show()
